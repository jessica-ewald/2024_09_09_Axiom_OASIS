# %% [markdown]
# # Compare PODs of different read outs
#
# The Axiom dataset contains CellPainting morphology data, plus various readouts related to cell viability / cytotoxicity. We computed points-of-departure (PODs) for each data type. Here, we compare PODs between: morphology, cell count, MTT, and LDH.
#
# CellPainting morphological endpoints reflect many biological processes. The remainder are various viability endpoints. MTT reflects the metabolic capacity of a given group of cells. Since more cells = more metabolism, it is usually correlated with cell count, however there can be metabolic impacts prior to cell death. Cell count reflects the combined effects of cell death and cell proliferation. Since hepatocytes are mainly non-dividing, we expect it to mainly reflect cell death. LDH is an enzyme released during necrosis, so it reflects a subset of cell death.
#
# We expect that CellPainting will have hits for the most compounds, next MTT, next cell count, and finally LDH. We expect that every LDH compound is included in the cell count compounds, and that the {LDH, cell count} compounds are also detected by CellPainting and MTT. We also expect the same general trend when comparing the actual POD values, where the sensitivity will be in the order CellPainting > MTT > cell count > LDH.

# %%
import polars as pl
import pandas as pd
from upsetplot import plot

# %%
# Compile all PODs into one dataframe
feat_path = "../1_snakemake/outputs/dino/mad_featselect"
prof_path = f"{feat_path}/profiles/mad_featselect.parquet"

data = pl.read_parquet(prof_path)

cc = pl.read_parquet(f"{feat_path}/curves/ccpods.parquet").filter(pl.col("all.pass") == True).select(["Metadata_Compound", "bmd"]).rename({"bmd": "Metadata_cc_POD"})
ldh = pl.read_parquet(f"{feat_path}/curves/ldhpods.parquet").filter(pl.col("all.pass") == True).select(["Metadata_Compound", "bmd"]).rename({"bmd": "Metadata_ldh_POD"})
mtt = pl.read_parquet(f"{feat_path}/curves/mttpods.parquet").filter(pl.col("all.pass") == True).select(["Metadata_Compound", "bmd"]).rename({"bmd": "Metadata_mtt_POD"})
morph = pl.read_parquet(f"{feat_path}/curves/pods.parquet").select(["Metadata_Compound", "bmd"]).rename({"bmd": "Metadata_morph_POD"})

data = data.join(cc, on="Metadata_Compound", how="left")
data = data.join(ldh, on="Metadata_Compound", how="left")
data = data.join(mtt, on="Metadata_Compound", how="left")
data = data.join(morph, on="Metadata_Compound", how="left")

all_pods = data.select([
    "Metadata_Compound",
    "Metadata_cc_POD",
    "Metadata_ldh_POD",
    "Metadata_mtt_POD",
    "Metadata_morph_POD",
]).unique()

# %% [markdown]
# ## Make Upset plot of intersects between lists

# %%
morph_set = set(all_pods.filter(~pl.col("Metadata_morph_POD").is_nan()).select("Metadata_Compound").to_series().to_list())
mtt_set = set(all_pods.filter(~pl.col("Metadata_mtt_POD").is_nan()).select("Metadata_Compound").to_series().to_list())
cc_set = set(all_pods.filter(~pl.col("Metadata_cc_POD").is_nan()).select("Metadata_Compound").to_series().to_list())
ldh_set = set(all_pods.filter(~pl.col("Metadata_ldh_POD").is_nan()).select("Metadata_Compound").to_series().to_list())

all_sets = [morph_set, mtt_set, cc_set, ldh_set]
set_labels = ['Morphology', 'MTT', 'Cell count', 'LDH']

# Create a mapping of element to set memberships
element_to_sets = {}
for i, s in enumerate(all_sets):
    for elem in s:
        if elem not in element_to_sets:
            element_to_sets[elem] = [0] * len(all_sets)
        element_to_sets[elem][i] = 1

# Convert mapping into a DataFrame
rows = []
for elem, membership in element_to_sets.items():
    rows.append(membership)
df = pd.DataFrame(rows, columns=set_labels)

# Group by sets and count occurrences
df['value'] = 1
upset_input = df.groupby(set_labels).count()
upset_input = upset_input['value']

# %%
plot(upset_input, sort_by="cardinality")
# Out:
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/upsetplot/plotting.py:795: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linewidth"].fillna(1, inplace=True)
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/upsetplot/plotting.py:796: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["facecolor"].fillna(self._facecolor, inplace=True)
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/upsetplot/plotting.py:797: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["edgecolor"].fillna(styles["facecolor"], inplace=True)
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/upsetplot/plotting.py:798: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   styles["linestyle"].fillna("solid", inplace=True)
# {'matrix': <Axes: >,
#  'shading': <Axes: >,
#  'totals': <Axes: >,
#  'intersections': <Axes: ylabel='Intersection size'>}

# %% [markdown]
# This plot shows that:
#
# 1) LDH & cell count hits are also detected by morphology (every hit) and MTT (8 exceptions)
# 2) There are many compounds detected by morphology but not by any other assay (n = 218)
# 3) There are also many compounds detected by only morphology and MTT (n = 171)
# 4) There are a small set of compounds detected by only MTT, but not by morphology (n = 34)

# %% [markdown]
# ## Scatterplots comparing PODs

# %% [markdown]
# After comparing POD values, we see exactly what we expect in most cases: morphology < MTT < cell count < LDH. There are a fair number of cases where the MTT POD is lower than the morphology POD (125/394, 32%), however keep in mind that there were many compounds with only morphology PODs (n = 218) versus compounds with only MTT PODs (n = 34).

# %%
from plotnine import ggplot, aes, geom_point, labs, theme_bw, geom_abline

plot = (
    ggplot(all_pods, aes(x='Metadata_morph_POD', y='Metadata_mtt_POD')) +
    geom_point(alpha=0.6) +
    geom_abline(slope=1, intercept=0, linetype='dashed', color='red') +
    labs(
        x='Morphology POD',
        y='MTT POD'
    ) +
    theme_bw()
)
plot.show()

plot = (
    ggplot(all_pods, aes(x='Metadata_morph_POD', y='Metadata_cc_POD')) +
    geom_point(alpha=0.6) +
    geom_abline(slope=1, intercept=0, linetype='dashed', color='red') +
    labs(
        x='Morphology POD',
        y='Cell count POD'
    ) +
    theme_bw()
)
print(plot)

plot = (
    ggplot(all_pods, aes(x='Metadata_morph_POD', y='Metadata_ldh_POD')) +
    geom_point(alpha=0.6) +
    geom_abline(slope=1, intercept=0, linetype='dashed', color='red') +
    labs(
        x='Morphology POD',
        y='LDH POD'
    ) +
    theme_bw()
)
plot.show()

plot = (
    ggplot(all_pods, aes(x='Metadata_mtt_POD', y='Metadata_cc_POD')) +
    geom_point(alpha=0.6) +
    geom_abline(slope=1, intercept=0, linetype='dashed', color='red') +
    labs(
        x='MTT POD',
        y='Cell count POD'
    ) +
    theme_bw()
)
plot.show()

plot = (
    ggplot(all_pods, aes(x='Metadata_mtt_POD', y='Metadata_ldh_POD')) +
    geom_point(alpha=0.6) +
    geom_abline(slope=1, intercept=0, linetype='dashed', color='red') +
    labs(
        x='MTT POD',
        y='LDH POD'
    ) +
    theme_bw()
)
plot.show()

plot = (
    ggplot(all_pods, aes(x='Metadata_cc_POD', y='Metadata_ldh_POD')) +
    geom_point(alpha=0.6) +
    geom_abline(slope=1, intercept=0, linetype='dashed', color='red') +
    labs(
        x='Cell count POD',
        y='LDH POD'
    ) +
    theme_bw()
)
plot.show()
# Out:
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 692 rows containing missing values.
# /var/folders/g0/nk06fpgs01z6zmr4x7kvp0g80000gp/T/ipykernel_39348/563485050.py:25: FutureWarning: Using print(plot) to draw and show the plot figure is deprecated and will be removed in a future version. Use plot.show().
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 866 rows containing missing values.
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 939 rows containing missing values.
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 870 rows containing missing values.
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 944 rows containing missing values.
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 950 rows containing missing values.

# %%
diff = (all_pods.select(["Metadata_morph_POD", "Metadata_mtt_POD"])
    .filter(~pl.col("Metadata_morph_POD").is_nan())
    .filter(~pl.col("Metadata_mtt_POD").is_nan())
    .with_columns((pl.col("Metadata_morph_POD") - pl.col("Metadata_mtt_POD")).alias("Diff"))
)

total = diff.shape[0]
mtt_lower = diff.filter(pl.col("Diff") > 0).shape[0]

print(total)
print(mtt_lower)
print(mtt_lower/total)
# Out:
# 394
# 125
# 0.31725888324873097

# %% [markdown]
# # Compare CP PODs across representations
#
# We want to know if some PODs are systematically lower/higher across representation types. We can compare:
#
# - gmd across all representations
# - lowest POD (whether gmd or cmd) across representations

# %%
import polars as pl

cp_dir = "../1_snakemake/outputs/cellprofiler/mad_featselect/curves"
cpcnn_dir = "../1_snakemake/outputs/cpcnn/mad_featselect/curves"
dino_dir = "../1_snakemake/outputs/dino/mad_featselect/curves"

# %% [markdown]
# First, compare the SD of DMSO and curve fit residuals across representations. Dino and CPCNN have much, much lower SD for gmd.

# %%
cp_gmd = pl.read_parquet(f"{cp_dir}/bmds.parquet").filter((pl.col("gene.id") == "gmd") & (pl.col("all.pass"))).with_columns(
    (pl.col("SDctrl")*3).alias("SDres_thresh")
)

cpcnn_gmd = pl.read_parquet(f"{cpcnn_dir}/bmds.parquet").filter((pl.col("gene.id") == "gmd") & (pl.col("all.pass"))).with_columns(
    (pl.col("SDctrl")*3).alias("SDres_thresh")
)

dino_gmd = pl.read_parquet(f"{dino_dir}/bmds.parquet").filter((pl.col("gene.id") == "gmd") & (pl.col("all.pass"))).with_columns(
    (pl.col("SDctrl")*3).alias("SDres_thresh")
)

# %%
print(cp_gmd.shape)
print(cpcnn_gmd.shape)
print(dino_gmd.shape)

all_gmd = pl.concat([
    cp_gmd.select(["Metadata_Compound", "bmd", "SDres", "SDctrl", "SDres_thresh"]).with_columns(pl.lit("cellprofiler").alias("Feat_type")),
    cpcnn_gmd.select(["Metadata_Compound", "bmd", "SDres", "SDctrl", "SDres_thresh"]).with_columns(pl.lit("cpcnn").alias("Feat_type")),
    dino_gmd.select(["Metadata_Compound", "bmd", "SDres", "SDctrl", "SDres_thresh"]).with_columns(pl.lit("dino").alias("Feat_type"))
], how="vertical")

all_gmd = all_gmd.with_columns(
    (pl.col("SDres") / pl.col("SDctrl")).alias("resid_ctrl")
)
# Out:
# (246, 25)
# (544, 25)
# (545, 25)

# %%
from plotnine import ggplot, aes, geom_histogram, labs, theme_bw, facet_wrap
import plotnine as pn

pn.options.figure_size = (16, 8)

plot = (
    ggplot(all_gmd, aes(x='SDctrl')) +
    geom_histogram() +
    labs(
        x='SD of DMSO',
    ) +
    facet_wrap("Feat_type") +
    theme_bw()
)
plot.show()

plot = (
    ggplot(all_gmd, aes(x='SDres')) +
    geom_histogram() +
    labs(
        x='SD of residuals',
    ) +
    facet_wrap("Feat_type") +
    theme_bw()
)
plot.show()

plot = (
    ggplot(all_gmd, aes(x='resid_ctrl')) +
    geom_histogram() +
    labs(
        x='Ratio of SDres/SDctrl',
    ) +
    facet_wrap("Feat_type") +
    theme_bw()
)
plot.show()
# Out:
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/stats/stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 65'. Pick better value with 'binwidth'.
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/stats/stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 2954'. Pick better value with 'binwidth'.
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/stats/stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 10782'. Pick better value with 'binwidth'.

# %%
all_gmd_filt = all_gmd.filter(
    (pl.col("SDres") < (pl.col("SDres_thresh")))
)

from plotnine import ggplot, aes, geom_histogram, labs, theme_bw, facet_wrap
import plotnine as pn

pn.options.figure_size = (16, 8)

plot = (
    ggplot(all_gmd_filt, aes(x='SDctrl')) +
    geom_histogram() +
    labs(
        x='SD of DMSO',
    ) +
    facet_wrap("Feat_type") +
    theme_bw()
)
plot.show()

plot = (
    ggplot(all_gmd_filt, aes(x='SDres')) +
    geom_histogram() +
    labs(
        x='SD of residuals',
    ) +
    facet_wrap("Feat_type") +
    theme_bw()
)
plot.show()

plot = (
    ggplot(all_gmd_filt, aes(x='resid_ctrl')) +
    geom_histogram() +
    labs(
        x='Ratio of SDres/SDctrl',
    ) +
    facet_wrap("Feat_type") +
    theme_bw()
)
plot.show()
# Out:
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/stats/stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 63'. Pick better value with 'binwidth'.
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/stats/stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 174'. Pick better value with 'binwidth'.
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/stats/stat_bin.py:109: PlotnineWarning: 'stat_bin()' using 'bins = 318'. Pick better value with 'binwidth'.

# %% [markdown]
# Next, compare the actual POD values for gmd fits that passed all qa/qc criteria.

# %%
gmd_df = all_gmd.pivot(values="bmd", index=["Metadata_Compound"], columns="Feat_type")

# %%
from plotnine import ggplot, aes, geom_point, labs, theme_bw, geom_abline
import plotnine as pn

pn.options.figure_size = (8, 8)

plot = (
    ggplot(gmd_df, aes(x='cellprofiler', y='cpcnn')) +
    geom_point(alpha=0.6) +
    geom_abline(slope=1, intercept=0, linetype='dashed', color='red') +
    labs(
        x='CellProfiler gmd POD',
        y='CPCNN gmd POD'
    ) +
    theme_bw()
)
plot.show()

plot = (
    ggplot(gmd_df, aes(x='cellprofiler', y='dino')) +
    geom_point(alpha=0.6) +
    geom_abline(slope=1, intercept=0, linetype='dashed', color='red') +
    labs(
        x='CellProfiler gmd POD',
        y='Dino gmd POD'
    ) +
    theme_bw()
)
plot.show()

plot = (
    ggplot(gmd_df, aes(x='dino', y='cpcnn')) +
    geom_point(alpha=0.6) +
    geom_abline(slope=1, intercept=0, linetype='dashed', color='red') +
    labs(
        x='Dino gmd POD',
        y='CPCNN gmd POD'
    ) +
    theme_bw()
)
plot.show()
# Out:
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 362 rows containing missing values.
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 359 rows containing missing values.
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 98 rows containing missing values.

# %%
r2_1 = gmd_df.select(pl.corr("cellprofiler", "cpcnn")).item() ** 2
print(f"CellProfiler v CPCNN R²: {r2_1}")

r2_2 = gmd_df.select(pl.corr("cellprofiler", "dino")).item() ** 2
print(f"CellProfiler v Dino R²: {r2_2}")

r2_3 = gmd_df.select(pl.corr("dino", "cpcnn")).item() ** 2
print(f"Dino v CPCNN R²: {r2_3}")
# Out:
# CellProfiler v CPCNN R²: 0.2875679937424395
# CellProfiler v Dino R²: 0.2885597943834156
# Dino v CPCNN R²: 0.7554342081583824

# %% [markdown]
# For learned representations, there are 3-4X as many PODs that pass all qa/qc criteria. Compared to CellProfiler, the learned representation PODs tend to be lower (more sensitive, if we trust them). There is also far more agreement between the learned representation PODs (R2 = 0.76) versus between CellProfiler and the learned representations (R2 = 0.29 for both).
#
#
# Next, we look at the final selected POD, which can be either a categorical MD or the global MD. Note that CPCNN has no categorical MD as it contains only one set of embeddings that aggregate information across channels.

# %%
cp_pod = pl.read_parquet(f"{cp_dir}/pods.parquet").with_columns(pl.lit("cellprofiler").alias("Feat_type"))
cpcnn_pod = pl.read_parquet(f"{cpcnn_dir}/pods.parquet").with_columns(pl.lit("cpcnn").alias("Feat_type"))
dino_pod = pl.read_parquet(f"{dino_dir}/pods.parquet").with_columns(pl.lit("dino").alias("Feat_type"))

all_pod = pl.concat([cp_pod, cpcnn_pod, dino_pod], how="vertical")
pod_df = all_pod.pivot(values="bmd", index=["Metadata_Compound"], columns="Feat_type")

# %%
from plotnine import ggplot, aes, geom_point, labs, theme_bw, geom_abline
import plotnine as pn

pn.options.figure_size = (8, 8)

plot = (
    ggplot(pod_df, aes(x='cellprofiler', y='cpcnn')) +
    geom_point(alpha=0.6) +
    geom_abline(slope=1, intercept=0, linetype='dashed', color='red') +
    labs(
        x='CellProfiler POD',
        y='CPCNN POD'
    ) +
    theme_bw()
)
plot.show()

plot = (
    ggplot(pod_df, aes(x='cellprofiler', y='dino')) +
    geom_point(alpha=0.6) +
    geom_abline(slope=1, intercept=0, linetype='dashed', color='red') +
    labs(
        x='CellProfiler POD',
        y='Dino POD'
    ) +
    theme_bw()
)
plot.show()

plot = (
    ggplot(pod_df, aes(x='dino', y='cpcnn')) +
    geom_point(alpha=0.6) +
    geom_abline(slope=1, intercept=0, linetype='dashed', color='red') +
    labs(
        x='Dino POD',
        y='CPCNN POD'
    ) +
    theme_bw()
)
plot.show()
# Out:
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 235 rows containing missing values.
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 204 rows containing missing values.
# /Users/jewald/miniforge3/envs/axiom/lib/python3.9/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 215 rows containing missing values.

# %%
r2_1 = pod_df.select(pl.corr("cellprofiler", "cpcnn")).item() ** 2
print(f"CellProfiler v CPCNN R²: {r2_1}")

r2_2 = pod_df.select(pl.corr("cellprofiler", "dino")).item() ** 2
print(f"CellProfiler v Dino R²: {r2_2}")

r2_3 = pod_df.select(pl.corr("dino", "cpcnn")).item() ** 2
print(f"Dino v CPCNN R²: {r2_3}")
# Out:
# CellProfiler v CPCNN R²: 0.5070885173143328
# CellProfiler v Dino R²: 0.49704877746046433
# Dino v CPCNN R²: 0.7342204484115866
